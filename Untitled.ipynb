# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import manifold, metrics, preprocessing, cluster

# Load Data
data = np.load('data/data_w_labels.npz')
Bdata = data['vec']     # Binder Word Vectors
Gdata = data['gVec']    # Google word Vectors
L1 = data['L1']         # Super Category labels
L2 = data['L2']         # Category labels
cats = data['cats']

# %%
counts = np.zeros((47,))
for num in L2:
    counts[int(num)] += 1
for idx, num in enumerate(counts):
    print (cats[idx], idx, ': ',num)
# Out:
# human 0 :  43.0
# emotion 1 :  20.0
# social action 2 :  16.0
# tool 3 :  27.0
# spatial property 4 :  2.0
# body part 5 :  15.0
# temporal property 6 :  1.0
# weather event 7 :  10.0
# perceptual state 8 :  1.0
# emotional property 9 :  5.0
# vehicle 10 :  20.0
# mental action 11 :  2.0
# document 12 :  5.0
# physical action 13 :  5.0
# plant 14 :  30.0
# abstract construct 15 :  40.0
# body state 16 :  1.0
# animal 17 :  30.0
# somatosensory property 18 :  4.0
# social property 19 :  4.0
# abstract action 20 :  2.0
# auditory property 21 :  1.0
# animal part 22 :  1.0
# general event 23 :  4.0
# social construct 24 :  19.0
# sound 25 :  11.0
# social event 26 :  35.0
# place 27 :  40.0
# locative action 28 :  14.0
# building part 29 :  3.0
# geological entity 30 :  3.0
# creative action 31 :  3.0
# furniture 32 :  7.0
# miscellaneous action 33 :  1.0
# electronic device 34 :  2.0
# multimodal property 35 :  8.0
# body action 36 :  10.0
# group 37 :  9.0
# mental state 38 :  3.0
# time period 39 :  10.0
# perceptual action 40 :  3.0
# instrument 41 :  20.0
# cognitive entity 42 :  10.0
# food 43 :  18.0
# distant object 44 :  2.0
# visual property 45 :  12.0
# cognitive property 46 :  2.0

# %%
for row in L2:
    print(cats[int(row)])
# Out:
# general event
# instrument
# human
# human
# abstract construct
# social construct
# social property
# document
# place
# animal
# vehicle
# abstract construct
# emotional property
# emotion
# animal
# place
# social construct
# social event
# locative action
# plant
# body part
# group
# social action
# human
# plant
# body action
# abstract construct
# group
# human
# weather event
# emotion
# tool
# instrument
# tool
# plant
# instrument
# human
# place
# social event
# tool
# social event
# place
# place
# furniture
# animal
# food
# sound
# cognitive entity
# instrument
# vehicle
# spatial property
# animal
# visual property
# physical action
# visual property
# plant
# vehicle
# social event
# document
# social action
# human
# food
# social event
# place
# plant
# physical action
# instrument
# creative action
# vehicle
# social construct
# human
# animal
# vehicle
# plant
# furniture
# place
# animal
# tool
# vehicle
# social event
# vehicle
# locative action
# plant
# tool
# place
# social action
# tool
# furniture
# food
# animal
# plant
# plant
# animal
# human
# instrument
# animal
# food
# group
# place
# social event
# sound
# instrument
# cognitive property
# distant object
# abstract construct
# food
# somatosensory property
# place
# tool
# human
# group
# electronic device
# tool
# plant
# sound
# group
# group
# place
# plant
# furniture
# human
# locative action
# animal
# plant
# abstract construct
# weather event
# physical action
# plant
# emotional property
# visual property
# time period
# multimodal property
# social event
# social construct
# emotion
# locative action
# emotion
# furniture
# physical action
# social event
# tool
# social event
# human
# human
# animal
# animal
# building part
# weather event
# body action
# emotion
# creative action
# human
# locative action
# instrument
# animal
# visual property
# human
# body part
# plant
# social event
# animal
# vehicle
# plant
# place
# social event
# visual property
# abstract action
# human
# emotion
# time period
# vehicle
# social construct
# time period
# social construct
# multimodal property
# sound
# body part
# abstract construct
# human
# social property
# place
# human
# abstract construct
# tool
# mental state
# animal part
# social action
# abstract construct
# building part
# social event
# instrument
# place
# body part
# general event
# animal
# creative action
# locative action
# weather event
# plant
# instrument
# abstract construct
# body part
# tool
# place
# perceptual action
# place
# social property
# emotion
# social event
# place
# sound
# social action
# human
# tool
# animal
# instrument
# emotion
# visual property
# physical action
# emotion
# social construct
# human
# emotion
# food
# sound
# weather event
# body part
# tool
# place
# food
# animal
# body part
# social event
# emotional property
# instrument
# instrument
# animal
# somatosensory property
# body action
# social action
# abstract construct
# social construct
# abstract construct
# place
# locative action
# tool
# place
# food
# social event
# cognitive entity
# animal
# place
# somatosensory property
# place
# weather event
# abstract construct
# geological entity
# abstract construct
# multimodal property
# social event
# cognitive entity
# social action
# emotion
# abstract construct
# place
# plant
# food
# body part
# emotion
# social event
# human
# emotion
# emotion
# human
# place
# group
# food
# tool
# tool
# body action
# social event
# place
# cognitive entity
# place
# place
# locative action
# weather event
# body action
# abstract construct
# human
# locative action
# body part
# abstract construct
# food
# weather event
# mental state
# vehicle
# body part
# perceptual action
# body state
# social construct
# emotional property
# temporal property
# abstract action
# auditory property
# emotion
# abstract construct
# emotion
# document
# abstract construct
# emotion
# human
# instrument
# locative action
# social event
# human
# food
# social event
# tool
# social construct
# social action
# human
# group
# animal
# animal
# social construct
# time period
# animal
# cognitive entity
# place
# animal
# body part
# body part
# plant
# social event
# food
# abstract construct
# social action
# visual property
# document
# time period
# body part
# abstract construct
# abstract construct
# plant
# place
# visual property
# body action
# cognitive entity
# social event
# tool
# social event
# abstract construct
# human
# place
# social event
# abstract construct
# human
# plant
# abstract construct
# emotional property
# tool
# tool
# animal
# social event
# instrument
# food
# animal
# human
# plant
# vehicle
# mental action
# social action
# social event
# abstract construct
# plant
# human
# human
# abstract construct
# multimodal property
# place
# human
# place
# abstract construct
# social event
# plant
# locative action
# abstract construct
# plant
# tool
# social event
# locative action
# plant
# mental action
# abstract construct
# visual property
# human
# place
# general event
# social event
# place
# vehicle
# abstract construct
# plant
# food
# social construct
# vehicle
# animal
# tool
# social construct
# perceptual state
# instrument
# place
# human
# tool
# vehicle
# sound
# sound
# time period
# emotion
# furniture
# visual property
# body part
# social action
# multimodal property
# social construct
# vehicle
# body action
# spatial property
# animal
# social construct
# social event
# somatosensory property
# human
# food
# tool
# social event
# cognitive property
# social action
# time period
# sound
# general event
# tool
# miscellaneous action
# social action
# geological entity
# place
# weather event
# place
# human
# vehicle
# vehicle
# abstract construct
# time period
# distant object
# body action
# cognitive entity
# social event
# furniture
# plant
# abstract construct
# food
# human
# group
# electronic device
# human
# social construct
# place
# abstract construct
# abstract construct
# body action
# sound
# document
# animal
# multimodal property
# tool
# food
# body part
# plant
# social action
# emotion
# weather event
# human
# vehicle
# social construct
# plant
# social event
# social construct
# instrument
# social construct
# vehicle
# instrument
# cognitive entity
# abstract construct
# instrument
# plant
# animal
# tool
# multimodal property
# social event
# vehicle
# abstract construct
# abstract construct
# human
# social action
# place
# human
# locative action
# mental state
# perceptual action
# geological entity
# social property
# locative action
# animal
# sound
# visual property
# abstract construct
# building part
# time period
# cognitive entity
# human
# emotion
# human
# cognitive entity
# body action
# human
# abstract construct
# social action
# instrument
# time period
# visual property
# multimodal property
# abstract construct
# place
